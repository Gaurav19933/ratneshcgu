# %%
import pandas as pd
import matplotlib.pyplot as plt 
df = pd.read_csv ('E:\Design\Aerogram\Eziostat Data\data (3).csv')
print (df)
# Out:
#                               ts  PM 1  PM 2.5  PM 10  Humidity  Temperature  \
# 0       2021-08-16T07:43:43.167Z    15      25     26     51.38        33.39
# 1       2021-08-16T07:34:14.245Z    12      17     25     50.10        33.98
# 2       2021-08-16T07:34:13.571Z    20      30     36     40.47        26.58
# 3       2021-08-16T07:34:14.220Z    17      26     28     51.77        33.37
# 4       2021-08-16T07:34:14.356Z    18      29     34     43.21        37.43
# ...                          ...   ...     ...    ...       ...          ...
# 353528  2021-08-18T05:23:28.071Z    39      58     71     62.97        34.58
# 353529  2021-08-18T05:23:47.311Z    33      49     61     36.54        30.44
# 353530  2021-08-18T05:23:47.622Z    35      53     69     59.73        33.69
# 353531  2021-08-18T05:23:47.753Z    41      65     76     62.91        34.58
# 353532  2021-08-18T05:23:48.091Z    40      61     73     53.37        33.89
#
# ...

# %%
df.shape
# Out:
# (353533, 13)

# %%
print(df)
# Out:
#                               ts  PM 1  PM 2.5  PM 10  Humidity  Temperature  \
# 0       2021-08-16T07:43:43.167Z    15      25     26     51.38        33.39
# 1       2021-08-16T07:34:14.245Z    12      17     25     50.10        33.98
# 2       2021-08-16T07:34:13.571Z    20      30     36     40.47        26.58
# 3       2021-08-16T07:34:14.220Z    17      26     28     51.77        33.37
# 4       2021-08-16T07:34:14.356Z    18      29     34     43.21        37.43
# ...                          ...   ...     ...    ...       ...          ...
# 353528  2021-08-18T05:23:28.071Z    39      58     71     62.97        34.58
# 353529  2021-08-18T05:23:47.311Z    33      49     61     36.54        30.44
# 353530  2021-08-18T05:23:47.622Z    35      53     69     59.73        33.69
# 353531  2021-08-18T05:23:47.753Z    41      65     76     62.91        34.58
# 353532  2021-08-18T05:23:48.091Z    40      61     73     53.37        33.89
#
# ...

# %%
dn1=df.query('Device_ID== "EZ-038" ', inplace = True) # select the require and filters rest
print(df)
# Out:
#                               ts  PM 1  PM 2.5  PM 10  Humidity  Temperature  \
# 6       2021-08-16T07:34:15.555Z    18      25     29     54.25        35.22
# 20      2021-08-16T07:34:26.116Z    18      23     26     54.03        35.22
# 35      2021-08-16T07:34:36.653Z    17      22     25     53.66        35.21
# 51      2021-08-16T07:34:46.586Z    15      23     28     53.73        35.21
# 63      2021-08-16T07:35:14.777Z    17      24     30     54.10        35.22
# ...                          ...   ...     ...    ...       ...          ...
# 353482  2021-08-18T05:31:12.565Z    40      57     72     61.58        34.65
# 353498  2021-08-18T05:23:07.392Z    40      60     71     64.00        34.58
# 353512  2021-08-18T05:23:17.115Z    38      57     72     63.30        34.58
# 353528  2021-08-18T05:23:28.071Z    39      58     71     62.97        34.58
# 353531  2021-08-18T05:23:47.753Z    41      65     76     62.91        34.58
#
# ...

# %%
time=df["ts"]
hum=df["Humidity"]
temp=df["Temperature"]
PM_one=df["PM 1"]
PM_two=df["PM 2.5"]
PM_ten=df["PM 10"]
#print(time)
plt.plot(time,PM_one,'ko--')
plt.plot(time,PM_two,'bs--')
plt.plot(time,PM_ten,'g^-')
plt.plot(time,hum,"yo--")
plt.plot(time,temp,"rs--")
plt.xlabel('Time')
plt.ylabel('PM')
plt.show()

# %%
sp=500
time=df.tail(sp)["ts"]
hum=df.tail(sp)["Humidity"]
temp=df.tail(sp)["Temperature"]
PM_one=df.tail(sp)["PM 1"]
PM_two=df.tail(sp)["PM 2.5"]
PM_ten=df.tail(sp)["PM 10"]
#print(time)
plt.plot(time,PM_one,'ko--')
plt.plot(time,PM_two,'bs--')
plt.plot(time,PM_ten,'g^-')
plt.plot(time,hum,"yo--")
plt.plot(time,temp,"rs--")
plt.xlabel('Time')
plt.ylabel('PM')
plt.show()

# %%
sp=1500
time=df.tail(sp)["ts"]
hum=df.tail(sp)["Humidity"]
temp=df.tail(sp)["Temperature"]
PM_one=df.tail(sp)["PM 1"]
PM_two=df.tail(sp)["PM 2.5"]
PM_ten=df.tail(sp)["PM 10"]
#print(time)
plt.plot(time,PM_one,'k--')
plt.plot(time,PM_two,'b--')
plt.plot(time,PM_ten,'g-')
plt.plot(time,hum,"y--")
plt.plot(time,temp,"r--")
plt.xlabel('Time')
plt.ylabel('PM')
plt.show()

# %%
sp=1500
time=df.tail(sp)["ts"]
hum=df.tail(sp)["Humidity"]
temp=df.tail(sp)["Temperature"]
PM_one=df.tail(sp)["PM 1"]
PM_two=df.tail(sp)["PM 2.5"]
PM_ten=df.tail(sp)["PM 10"]
#print(time)

fig, (ax1, ax2) = plt.subplots(2, 1)
# make a little extra space between the subplots
fig.subplots_adjust(hspace=0.5)

ax1.plot(time,PM_one,time, PM_two)
ax1.set_xlim(0, 5)
ax1.set_xlabel('time')
ax1.set_ylabel('PM1 and PM2')
ax1.grid(True)
plt.show()

# %%
dn1=df.query('Device_ID== "EZ-038" ', inplace = True) # select the require and filters rest
print(df)
# Out:
# Empty DataFrame
# Columns: [ts, PM 1, PM 2.5, PM 10, Humidity, Temperature, RTC_Time, sensorSeven, sensorEight, sensorNine, sensorTen, MAC_ID, Device_ID]
# Index: []

# %%
# Out:
# Empty DataFrame
# Columns: [ts, PM 1, PM 2.5, PM 10, Humidity, Temperature, RTC_Time, sensorSeven, sensorEight, sensorNine, sensorTen, MAC_ID, Device_ID]
# Index: []

# %%
df.tail(100)
# Out:
#                               ts  PM 1  PM 2.5  PM 10  Humidity  Temperature  \
# 352097  2021-08-20T12:44:28.755Z    23      34     42     76.22        30.85
# 352100  2021-08-20T12:44:48.623Z    22      33     42     76.20        30.85
# 352114  2021-08-20T12:44:58.270Z    22      34     42     76.21        30.85

#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'PM1'

# %%
import numpy as np
pm1=[]
pm2=[]
pm10=[]
dn=df["Device_ID"]
time=df["ts"]
PM_1=df["PM 1"]
PM_2=df["PM 2.5"]
PM_10=df["PM 10"]
dn=
# Out:
# 0         EZ-039
# 1         EZ-027
# 2         EZ-042
# 3         EZ-039
# 4         EZ-029
#            ...
# 353528    EZ-038
# 353529    EZ-042
# 353530    EZ-027
# 353531    EZ-038
# 353532    EZ-035
# Name: Device_ID, Length: 353533, dtype: object

# %%
pm1=df[(df["PM 1"] < 100) & (df["Device_ID"] !="EZ-038")]
print(pm1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PM 1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-bf58a62a3c66> in <module>
# ...

# %%
for i in range(len(time)):
    PM_1[i].append(pm1[i])
print(pm1)

# %%
sp=5
time=df.tail(sp)["ts"]
hum=df.tail(sp)["Humidity"]
temp=df.tail(sp)["Temperature"]
PM_one=df.tail(sp)["PM 1"]
PM_two=df.tail(sp)["PM 2.5"]
PM_ten=df.tail(sp)["PM 10"]
#print(time)
plt.plot(time,PM_one,'ko--')
plt.plot(time,PM_two,'bs--')
plt.plot(time,PM_ten,'g^-')
plt.plot(time,hum,"yo--")
plt.plot(time,temp,"rs--")
plt.xlabel('Time')
plt.ylabel('PM')
plt.show()

# %%
dn=df.tail(sp)["Device_ID"]
print(dn)
data=[]
for i in range(len(dn)):
    data.append(dn[i])
    print(data)
# Out:
# 353528    EZ-038
# 353529    EZ-042
# 353530    EZ-027
# 353531    EZ-038
# 353532    EZ-035
# Name: Device_ID, dtype: object
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-e8bf5d714392> in <module>
#       3 data=[]
#       4 for i in range(len(dn)):
# ----> 5     data.append(dn[i])
#       6     print(data)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# ...

# %%
plt.plot(time,PM_two)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt 
E:\Design\Aerogram\Eziostat Data
df = pd.read_csv ('C:\Users\hp\OneDrive\Desktop\employees.csv')
print (df)
# Out:
#   File "<ipython-input-104-9beeccb993f9>", line 3
#     df = pd.read_csv ('C:\Users\hp\OneDrive\Desktop\employees.csv')
#                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
C:\Users\hp\OneDrive\Desktop

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'name':['Jane','John','Ashley','Mike','Emily','Jack','Catlin'],
'ctg':['A','A','C','B','B','C','B'],
'val':np.random.random(7).round(2),
'val2':np.random.randint(1,10, size=7)})
print(df)
# Out:
#      name ctg   val  val2
# 0    Jane   A  1.00     3
# 1    John   A  0.74     2
# 2  Ashley   C  0.68     5
# 3    Mike   B  0.06     3
# 4   Emily   B  0.81     8
# 5    Jack   C  0.14     4
# 6  Catlin   B  0.02     2

# %%
df1=df[df.val > 0.5]
print(df1)
print(df1.size)
print(df.size)
# Out:
#      name ctg   val  val2
# 0    Jane   A  1.00     3
# 1    John   A  0.74     2
# 2  Ashley   C  0.68     5
# 4   Emily   B  0.81     8
# 16
# 28

# %%
df2=df[df.name!= 'Jane']
print(df2)
# Out:
#      name ctg   val  val2
# 1    John   A  0.74     2
# 2  Ashley   C  0.68     5
# 3    Mike   B  0.06     3
# 4   Emily   B  0.81     8
# 5    Jack   C  0.14     4
# 6  Catlin   B  0.02     2
